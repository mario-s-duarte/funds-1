# %%
from degiro_connector.trading.api import API as TradingAPI

from degiro_connector.trading.models.credentials import build_credentials

# %%
credentials = build_credentials(
    override={
         "username": "mariosilvaduarte",
         "password": "85L$PTG/Y5WwRtt",
         # "totp_secret_key": "TEXT_PLACEHOLDER",  # For 2FA
     },
)
trading_api = TradingAPI(credentials=credentials)
trading_api.connect()

# FETCH CONFIG TABLE
client_details_table = trading_api.get_client_details()

client_details_table
# Out:
# login_error:{'status': 12, 'statusText': 'inAppTOTPNeeded'}
# ---------------------------------------------------------------------------
# DeGiroConnectionError                     Traceback (most recent call last)
# Cell In[3], line 9
#       1 credentials = build_credentials(
#       2     override={
#       3          "username": "mariosilvaduarte",
#    (...)
#       6      },
#       7 )
#       8 trading_api = TradingAPI(credentials=credentials)
# ----> 9 trading_api.connect()
#      11 # FETCH CONFIG TABLE
#      12 client_details_table = trading_api.get_client_details()
#
# File c:\MyPrograms\miniconda3\envs\fundos\Lib\site-packages\degiro_connector\core\abstracts\abstract_action.py:69, in AbstractAction.__call__(self, *args, **kwargs)
#      68 def __call__(self, *args, **kwargs):
# ---> 69     return self.call(*args, **kwargs)
#
# File c:\MyPrograms\miniconda3\envs\fundos\Lib\site-packages\degiro_connector\trading\actions\action_connect.py:132, in ActionConnect.call(self)
#     129 credentials = self.credentials
#     130 logger = self.logger
# --> 132 connection_storage.session_id = self.get_session_id(
#     133     credentials=credentials,
#     134     logger=logger,
#     135     session=session,
#     136 )
#     138 return connection_storage.session_id
#
# File c:\MyPrograms\miniconda3\envs\fundos\Lib\site-packages\degiro_connector\trading\actions\action_connect.py:117, in ActionConnect.get_session_id(cls, credentials, session, logger)
#     114     raise MaintenanceError('Scheduled Maintenance.', login_error)
#     116 if login_sucess is None:
# --> 117     raise DeGiroConnectionError("No session id returned.", login_error)
#     119 logger.info(
#     120     "login_sucess: %s",
#     121     login_sucess.model_dump(mode="python", by_alias=True, exclude_none=True),
#     122 )
#     124 return login_sucess.session_id
#
# DeGiroConnectionError: No session id returned.
